# %%
from utils_martina.utils_explainer import *
from utils_martina.routine_2 import *

# %%
list_epochs = [500]
list_lr = [0.001, 0.01, 0.1]
list_discriminator = ["SimpleDiscriminator", "TopKPoolingDiscriminator"]

for epochs in list_epochs:
    for lr in list_lr:
        for discriminator in list_discriminator:
            print(f"   Epochs {epochs} - Learning rate {lr} - Discriminator {discriminator}")

            create_explainer_json(epochs=epochs, lr=lr, discriminator=discriminator)

            routine()
# Out:
#    Epochs 500 - Learning rate 0.001 - Discriminator SimpleDiscriminator
# Removed folder and its contents: .\data\cache\explainers\GCS-28e49373646e3a1aa4f78d3b3cf52c7d
# 2025-04-30 16:41:08,619 | INFO | 19112 - Loading: GCS-28e49373646e3a1aa4f78d3b3cf52c7d
# 2025-04-30 16:41:08,972 | INFO | 19112 - Created: GCS-28e49373646e3a1aa4f78d3b3cf52c7d
# 2025-04-30 16:41:08,972 | INFO | 19112 - Instantiating: src.oracle.nn.gcn.DownstreamGCN
# 2025-04-30 16:41:08,981 | INFO | 19112 - Instantiating: torch.optim.RMSprop
# 2025-04-30 16:41:08,982 | INFO | 19112 - Instantiating: torch.nn.CrossEntropyLoss
# 2025-04-30 16:41:09,024 | INFO | 19112 - Creating: OracleTorch-4144b22a0e6992671e8c29c0ee5f5881
# 2025-04-30 16:41:09,352 | INFO | 19112 - epoch = 0 ---> loss = 0.6909	 accuracy = 0.5091
# 2025-04-30 16:41:09,678 | INFO | 19112 - epoch = 1 ---> loss = 0.6854	 accuracy = 0.5221
# 2025-04-30 16:41:09,900 | INFO | 19112 - epoch = 2 ---> loss = 0.6793	 accuracy = 0.5182
# ...
