# %%
import pickle
from utils_martina.my_utils import *

# %%
# Save eval_manager to file
file_name = get_most_recent_file("..\\..\\explainability\GRETEL-repo\\output\\logs\\").split('.')[0]

# %%
with open(f'cf_dict_{file_name}.pkl', 'rb') as f:
    cf_dict = pickle.load(f)

# %%
cf_dict
# Out:
# {0: <src.dataset.instances.graph.GraphInstance at 0x16b1bcf2130>,
#  1: <src.dataset.instances.graph.GraphInstance at 0x16b2d711f70>,
#  2: <src.dataset.instances.graph.GraphInstance at 0x16b2d7150d0>,
#  3: <src.dataset.instances.graph.GraphInstance at 0x16b2d715280>,
#  4: <src.dataset.instances.graph.GraphInstance at 0x16b2d7153a0>,
#  5: <src.dataset.instances.graph.GraphInstance at 0x16b2d7154c0>,
#  6: <src.dataset.instances.graph.GraphInstance at 0x16b2d7155e0>,
#  7: <src.dataset.instances.graph.GraphInstance at 0x16b2d715700>,
#  8: <src.dataset.instances.graph.GraphInstance at 0x16b2d711f10>,
#  9: <src.dataset.instances.graph.GraphInstance at 0x16b2d711d00>,
#  10: <src.dataset.instances.graph.GraphInstance at 0x16b2d711c40>,
#  11: <src.dataset.instances.graph.GraphInstance at 0x16b2d711af0>,
#  12: <src.dataset.instances.graph.GraphInstance at 0x16b2d7118b0>,
#  13: <src.dataset.instances.graph.GraphInstance at 0x16b2d7116a0>,
# ...

# %%
for i in range(5):
    print(cf_dict[784][i][1].id)
# Out:
# 275
# 238
# 273
# 274
# 231
