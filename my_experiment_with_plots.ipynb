# %%
import os
import torch
import random
import numpy as np

import networkx as nx
import matplotlib.pyplot as plt

from src.evaluation.evaluator_manager import EvaluatorManager
from src.evaluation.evaluator_manager_do import EvaluatorManager as PairedEvaluatorManager
from src.evaluation.evaluator_manager_triplets import EvaluatorManager as TripletsEvaluatorManager

from src.utils.context import Context

# %% [markdown]
# ## Eliminazione cache dataset

# %%
elimina_cache_dataset = True

if elimina_cache_dataset:
    cartella = ".\data\cache\datasets"

    for file in os.listdir(cartella):
        if file.startswith("GCS-"):  # Controlla se il file inizia con "GCS-"
            percorso_completo = os.path.join(cartella, file)
            if os.path.isfile(percorso_completo):
                os.remove(percorso_completo)
                print(f"Eliminato: {percorso_completo}")
# Out:
# Eliminato: .\data\cache\datasets\GCS-189d68770f99189694c24d6a27f87039

# %% [markdown]
# ## Run Gretel experiment

# %%
# %%capture captured_output

path = 'config/GCS-GCN.jsonc'
# path = 'config/GCS-SVM.jsonc'
# path = 'config/GCS-KNN.jsonc'

print(f"Generating context for: {path}")
context = Context.get_context(path)
context.run_number = -1

context.logger.info(f"Executing: {context.config_file} Run: {context.run_number}")
context.logger.info(
    "Creating the evaluation manager......................................................."
)

if 'doe-triplets' in context.conf:
    context.logger.info("Creating the TRIPLET evaluators........................................................")
    eval_manager = TripletsEvaluatorManager(context)
if 'do-pairs' in context.conf:
    context.logger.info("Creating the PAIRED evaluators...............................................................")
    eval_manager = PairedEvaluatorManager(context)
else:
    context.logger.info("Creating the evaluators...............................................................")
    eval_manager = EvaluatorManager(context)

context.logger.info(
    "Evaluating the explainers............................................................."
)

eval_manager.evaluate()
# Out:
# 2025-01-28 10:22:43,-1405591510 | INFO | 23968 - Executing: config/GCS-GCN.jsonc Run: -1
# 2025-01-28 10:22:43,-1405591258 | INFO | 23968 - Creating the evaluation manager.......................................................
# 2025-01-28 10:22:43,-1405591179 | INFO | 23968 - Creating the PAIRED evaluators...............................................................
# 2025-01-28 10:22:43,-1405590943 | INFO | 23968 - Creating: GCS-189d68770f99189694c24d6a27f87039
# 2025-01-28 10:22:43,-1405590927 | INFO | 23968 - Instantiating: src.dataset.generators.gcs.GCS
# 2025-01-28 10:22:52,-1405582126 | INFO | 23968 - Saved: GCS-189d68770f99189694c24d6a27f87039
# 2025-01-28 10:22:52,-1405582045 | INFO | 23968 - Created: GCS-189d68770f99189694c24d6a27f87039
# 2025-01-28 10:22:52,-1405581999 | INFO | 23968 - Instantiating: src.oracle.nn.gcn.DownstreamGCN
# 2025-01-28 10:22:52,-1405581985 | INFO | 23968 - Instantiating: torch.optim.RMSprop
# 2025-01-28 10:22:52,-1405581985 | INFO | 23968 - Instantiating: torch.nn.CrossEntropyLoss
# 2025-01-28 10:22:53,-1405581845 | INFO | 23968 - Creating: OracleTorch-1fb2b28bfeb944b6430ae525efb21afb
# 2025-01-28 10:22:54,-1405580033 | INFO | 23968 - epoch = 0 ---> loss = 0.6917	 accuracy = 0.5109
# 2025-01-28 10:22:56,-1405578712 | INFO | 23968 - epoch = 1 ---> loss = 0.6885	 accuracy = 0.6700
# 2025-01-28 10:22:57,-1405577153 | INFO | 23968 - epoch = 2 ---> loss = 0.6857	 accuracy = 0.7420
# 2025-01-28 10:22:59,-1405575878 | INFO | 23968 - epoch = 3 ---> loss = 0.6830	 accuracy = 0.7476
# 2025-01-28 10:23:00,-1405574448 | INFO | 23968 - epoch = 4 ---> loss = 0.6802	 accuracy = 0.7495
# 2025-01-28 10:23:01,-1405573265 | INFO | 23968 - epoch = 5 ---> loss = 0.6776	 accuracy = 0.7453
# 2025-01-28 10:23:02,-1405571927 | INFO | 23968 - epoch = 6 ---> loss = 0.6747	 accuracy = 0.7595
# 2025-01-28 10:23:04,-1405570417 | INFO | 23968 - epoch = 7 ---> loss = 0.6718	 accuracy = 0.7486
# 2025-01-28 10:23:05,-1405568968 | INFO | 23968 - epoch = 8 ---> loss = 0.6691	 accuracy = 0.7514
# 2025-01-28 10:23:07,-1405567490 | INFO | 23968 - epoch = 9 ---> loss = 0.6660	 accuracy = 0.7675
# 2025-01-28 10:23:08,-1405565912 | INFO | 23968 - epoch = 10 ---> loss = 0.6631	 accuracy = 0.7642
# 2025-01-28 10:23:10,-1405564497 | INFO | 23968 - epoch = 11 ---> loss = 0.6601	 accuracy = 0.7637
# 2025-01-28 10:23:12,-1405562794 | INFO | 23968 - epoch = 12 ---> loss = 0.6571	 accuracy = 0.7642
# 2025-01-28 10:23:13,-1405561503 | INFO | 23968 - epoch = 13 ---> loss = 0.6545	 accuracy = 0.7680
# 2025-01-28 10:23:14,-1405560607 | INFO | 23968 - epoch = 14 ---> loss = 0.6517	 accuracy = 0.7675
# 2025-01-28 10:23:15,-1405559727 | INFO | 23968 - epoch = 15 ---> loss = 0.6494	 accuracy = 0.7689
# 2025-01-28 10:23:16,-1405558847 | INFO | 23968 - epoch = 16 ---> loss = 0.6460	 accuracy = 0.7713
# 2025-01-28 10:23:17,-1405557243 | INFO | 23968 - epoch = 17 ---> loss = 0.6436	 accuracy = 0.7652
# 2025-01-28 10:23:18,-1405556077 | INFO | 23968 - epoch = 18 ---> loss = 0.6411	 accuracy = 0.7670
# 2025-01-28 10:23:19,-1405555024 | INFO | 23968 - epoch = 19 ---> loss = 0.6384	 accuracy = 0.7689
# 2025-01-28 10:23:21,-1405553464 | INFO | 23968 - Test accuracy = 0.7680
# 2025-01-28 10:23:21,-1405553369 | INFO | 23968 - OracleTorch trained on cpu in: 28.378570079803467 secs
# 2025-01-28 10:23:21,-1405553257 | INFO | 23968 - Saved: OracleTorch-1fb2b28bfeb944b6430ae525efb21afb
# 2025-01-28 10:23:21,-1405553165 | INFO | 23968 - Created: OracleTorch-1fb2b28bfeb944b6430ae525efb21afb
# 2025-01-28 10:23:21,-1405553149 | INFO | 23968 - Instantiating: src.evaluation.evaluation_metric_ged.GraphEditDistanceMetric
# 2025-01-28 10:23:21,-1405553055 | INFO | 23968 - Created: DCESExplainer-1bc3bcc16827475dc8d2312ac0f6154d
# 2025-01-28 10:23:21,-1405552976 | INFO | 23968 - Evaluating the explainers.............................................................
# 2025-01-28 10:23:21,-1405552937 | INFO | 23968 - Evaluating instance with id 5
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 28
#      22     eval_manager = EvaluatorManager(context)
#      24 context.logger.info(
#      25     "Evaluating the explainers............................................................."
#      26 )
# ---> 28 eval_manager.evaluate()
#
# File c:\Users\zanno\explainability\GRETEL-repo\src\evaluation\evaluator_manager_do.py:85, in EvaluatorManager.evaluate(self)
#      76 """Evaluates each combination of dataset-oracle-explainer using the chosen evaluation metrics
#      77
#      78 -------------
#    (...)
#      82 OUTPUT: None
#      83 """
#      84 for evaluator in self._evaluators:
# ---> 85     evaluator.evaluate()
#      87 for evaluator in self._evaluators:
#      88     dataset = evaluator.dataset
#
# File c:\Users\zanno\explainability\GRETEL-repo\src\evaluation\evaluator_base.py:128, in Evaluator.evaluate(self)
#     126 for metric in self._evaluation_metrics:
#     127     if(metric._special):
# --> 128         val, counterfactual = metric.evaluate(inst, None, self._oracle,self._explainer,self._data)
#     129         self._results[Context.get_fullname(metric)].append({"id":str(inst.id),"value":val})
#     130         self._explanations.append(counterfactual)
#
# File c:\Users\zanno\explainability\GRETEL-repo\src\evaluation\evaluation_metric_runtime.py:16, in RuntimeMetric.evaluate(self, instance_1, instance_2, oracle, explainer, dataset)
#      14 def evaluate(self, instance_1 , instance_2 , oracle : Oracle=None, explainer : Explainer=None, dataset = None):
#      15     start_time = time.time()
# ---> 16     counterfactual = explainer.explain(instance_1)
#      17     end_time = time.time()
#      18     # giving the same id to the counterfactual and the original instance
#
# File c:\Users\zanno\explainability\GRETEL-repo\src\explainer\search\dces.py:39, in DCESExplainer.explain(self, instance)
#      37 min_ctf_dist = sys.float_info.max
#      38 for ctf_candidate in self.dataset.instances:
# ---> 39     candidate_label, node_embeddings = self.oracle.predict(ctf_candidate, return_embeddings=True) ## Chiama oracle_base.predict
#      40     print(f"node embeddings: {node_embeddings}")
#      42     if input_label != candidate_label:
#
# File c:\Users\zanno\explainability\GRETEL-repo\src\core\oracle_base.py:44, in Oracle.predict(self, data_instance, return_embeddings)
#      36 # # print(f"data_instance.num_nodes: {data_instance.num_nodes}")
#      37
#      38 # print("\n>> PREVISIONE <<")
#      39
#      40 # output = self._real_predict(data_instance)
#      41 # print(f"Prediction: {output}")
#      43 if data_instance.id == 2000: # Togli!
# ---> 44     3/0
#      47 if return_embeddings:
#      48     output, embeddings = self._real_predict(data_instance,return_embeddings=True)
#
# ZeroDivisionError: division by zero

# %%
import pickle

# Ricava il nome del file di log più recente
file_name = max(os.listdir("..\\..\\explainability\GRETEL-repo\\output\\logs\\"), key=lambda f: os.path.getmtime(os.path.join("..\\..\\explainability\GRETEL-repo\\output\\logs\\", f)))
file_name = file_name.split('.')[0]
file_name = "..\\..\\explainability\GRETEL-repo\\output\\eval_manager\\" + file_name + ".pkl"

with open(file_name, 'wb') as f:
    pickle.dump(eval_manager, f)

# %%
print(captured_output.stdout)
# Out:
# Generating context for: config/GCS-GCN.jsonc
# ----------------------------------------------------------------
# data_instance.id: 5
# data_instance.label: 0
# Prediction: 0
# ----------------------------------------------------------------
# data_instance.id: 0
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0111, 0.0131]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0087, 0.0103]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 2
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0095, 0.0109]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 3
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0029, 0.0034]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 4
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0156, 0.0165]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 5
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0079, 0.0088]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 6
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0061, 0.0072]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 7
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0008, 0.0013]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 8
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0148, 0.0165]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 9
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0024, 0.0029]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 10
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0499, 0.0545]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 11
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0612, 0.0672]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 12
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0110, 0.0123]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 13
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0021, 0.0029]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 14
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0120, 0.0140]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 15
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0188, 0.0208]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 16
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0089, 0.0103]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 17
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0030, 0.0033]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 18
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0040, 0.0047]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 19
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0076, 0.0086]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 20
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0047, 0.0057]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 21
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0549, 0.0595]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 22
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0030, 0.0034]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 23
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0025, 0.0037]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 24
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0166, 0.0195]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 25
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0141, 0.0167]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 26
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0053, 0.0067]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 27
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0111, 0.0128]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 28
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0101, 0.0115]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 29
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0175, 0.0188]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 30
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0066, 0.0079]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 31
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0046, 0.0058]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 32
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0109, 0.0129]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 33
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0311, 0.0342]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 34
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0204, 0.0225]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 35
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0064, 0.0076]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 36
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0072, 0.0084]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 37
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0034, 0.0035]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 38
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0089, 0.0102]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 39
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0049, 0.0056]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 40
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0139, 0.0154]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 41
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0216, 0.0235]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 42
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0095, 0.0111]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 43
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0102, 0.0117]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 44
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0016, 0.0023]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 45
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0107, 0.0124]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 46
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0186, 0.0213]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 47
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0103, 0.0123]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 48
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0063, 0.0076]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 49
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0174, 0.0198]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 50
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0158, 0.0170]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 51
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0049, 0.0060]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 52
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0172, 0.0185]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 53
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0436, 0.0469]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 54
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0089, 0.0105]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 55
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0067, 0.0078]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 56
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0039, 0.0047]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 57
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0100, 0.0114]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 58
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0041, 0.0050]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 59
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0180, 0.0203]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 60
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0122, 0.0137]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 61
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0119, 0.0134]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 62
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0068, 0.0076]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 63
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0071, 0.0081]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 64
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0063, 0.0075]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 65
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0113, 0.0131]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 66
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0044, 0.0053]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 67
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0137, 0.0159]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 68
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0026, 0.0034]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 69
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0051, 0.0058]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 70
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0278, 0.0295]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 71
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0035, 0.0041]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 72
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0275, 0.0295]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 73
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0521, 0.0564]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 74
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0138, 0.0152]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 75
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0072, 0.0084]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 76
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0048, 0.0058]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 77
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0152, 0.0167]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 78
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0111, 0.0124]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 79
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0134, 0.0156]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 80
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0126, 0.0147]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 81
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0089, 0.0109]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 82
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0105, 0.0127]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 83
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0125, 0.0142]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 84
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0103, 0.0122]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 85
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0152, 0.0176]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 86
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0099, 0.0109]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 87
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0052, 0.0061]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 88
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0119, 0.0135]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 89
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0018, 0.0023]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 90
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0067, 0.0081]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 91
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0100, 0.0113]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 92
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0044, 0.0054]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 93
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0228, 0.0251]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 94
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0205, 0.0226]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 95
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0026, 0.0033]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 96
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0037, 0.0045]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 97
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0076, 0.0088]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 98
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0220, 0.0246]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 99
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0148, 0.0171]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 100
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0083, 0.0097]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 101
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0024, 0.0028]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 102
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0057, 0.0068]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 103
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0099, 0.0111]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 104
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0254, 0.0273]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 105
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0086, 0.0099]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 106
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0134, 0.0152]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 107
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0074, 0.0084]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 108
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0031, 0.0038]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 109
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0056, 0.0066]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 110
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0036, 0.0043]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 111
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0165, 0.0169]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 112
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0213, 0.0234]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 113
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0434, 0.0469]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 114
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0095, 0.0100]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 115
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0572, 0.0619]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 116
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0086, 0.0101]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 117
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0296, 0.0334]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 118
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0086, 0.0096]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 119
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0068, 0.0073]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 120
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0749, 0.0817]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 121
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0003, 0.0006]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 122
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0184, 0.0204]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 123
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0214, 0.0239]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 124
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0096, 0.0112]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 125
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0535, 0.0588]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 126
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0173, 0.0182]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 127
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0127, 0.0136]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 128
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0087, 0.0096]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 129
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0130, 0.0148]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 130
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0039, 0.0044]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 131
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0043, 0.0054]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 132
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0070, 0.0082]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 133
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0092, 0.0108]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 134
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0196, 0.0218]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 135
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0165, 0.0187]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 136
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0078, 0.0089]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 137
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0186, 0.0207]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 138
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0283, 0.0297]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 139
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0353, 0.0380]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 140
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0077, 0.0089]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 141
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0057, 0.0069]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 142
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0046, 0.0057]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 143
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0099, 0.0115]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 144
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0., 0.]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 145
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0099, 0.0114]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 146
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0076, 0.0089]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 147
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0287, 0.0304]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 148
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0090, 0.0102]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 149
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0103, 0.0117]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 150
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0082, 0.0099]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 151
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0259, 0.0283]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 152
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0097, 0.0119]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 153
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0141, 0.0162]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 154
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0056, 0.0065]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 155
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0069, 0.0079]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 156
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0092, 0.0103]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 157
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0146, 0.0162]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 158
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0130, 0.0139]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 159
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0053, 0.0061]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 160
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0196, 0.0209]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 161
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0055, 0.0066]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 162
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0021, 0.0026]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 163
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0015, 0.0018]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 164
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0105, 0.0119]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 165
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0023, 0.0029]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 166
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0121, 0.0137]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 167
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0082, 0.0094]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 168
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0246, 0.0266]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 169
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0076, 0.0087]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 170
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0102, 0.0116]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 171
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0072, 0.0089]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 172
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0095, 0.0113]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 173
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0095, 0.0106]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 174
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0053, 0.0060]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 175
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0077, 0.0088]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 176
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0050, 0.0060]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 177
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0035, 0.0046]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 178
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0385, 0.0414]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 179
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0138, 0.0155]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 180
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0124, 0.0146]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 181
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0055, 0.0068]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 182
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0135, 0.0158]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 183
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0179, 0.0203]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 184
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0097, 0.0115]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 185
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0095, 0.0114]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 186
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0070, 0.0084]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 187
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0052, 0.0063]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 188
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0064, 0.0076]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 189
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0137, 0.0158]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 190
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0105, 0.0118]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 191
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0081, 0.0094]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 192
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0268, 0.0294]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 193
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0098, 0.0116]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 194
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0092, 0.0109]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 195
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0091, 0.0113]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 196
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0407, 0.0438]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 197
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0119, 0.0139]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 198
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0227, 0.0257]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 199
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0100, 0.0120]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 200
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0088, 0.0106]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 201
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0111, 0.0127]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 202
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0556, 0.0599]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 203
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0062, 0.0072]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 204
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0295, 0.0312]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 205
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0384, 0.0409]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 206
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0005, 0.0010]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 207
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0014, 0.0019]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 208
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0053, 0.0060]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 209
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0225, 0.0233]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 210
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0017, 0.0021]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 211
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0533, 0.0574]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 212
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0316, 0.0334]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 213
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0050, 0.0057]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 214
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0010, 0.0013]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 215
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0525, 0.0565]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 216
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0106, 0.0116]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 217
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0., 0.]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 218
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0073, 0.0084]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 219
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0503, 0.0542]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 220
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0002, 0.0003]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 221
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0000, 0.0001]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 222
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0375, 0.0400]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 223
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0051, 0.0060]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 224
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0672, 0.0730]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 225
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0132, 0.0151]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 226
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[2.2954e-05, 0.0000e+00]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 227
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0076, 0.0086]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 228
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0331, 0.0350]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 229
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0184, 0.0199]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 230
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0417, 0.0443]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 231
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0148, 0.0165]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 232
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1321, 0.1441]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 233
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0259, 0.0286]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 234
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0349, 0.0370]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 235
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0598, 0.0646]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 236
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0066, 0.0079]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 237
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0187, 0.0213]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 238
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0097, 0.0109]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 239
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0267, 0.0296]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 240
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1048, 0.1147]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 241
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0132, 0.0146]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 242
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0057, 0.0065]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 243
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0449, 0.0492]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 244
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0156, 0.0175]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 245
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0365, 0.0399]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 246
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0062, 0.0072]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 247
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0294, 0.0321]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 248
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0321, 0.0351]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 249
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0497, 0.0549]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 250
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0398, 0.0439]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 251
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0005, 0.0007]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 252
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0535, 0.0592]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 253
# data_instance.label: 1
# Prediction: 0
# ...
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0083, 0.0090]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1917
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0736, 0.0802]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1918
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.3099, 0.3403]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1919
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0935, 0.1015]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1920
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0400, 0.0432]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1921
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0125, 0.0139]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1922
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0518, 0.0548]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1923
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.2476, 0.2663]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1924
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.2981, 0.3278]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1925
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1877, 0.2041]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1926
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1409, 0.1528]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1927
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0219, 0.0242]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1928
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0169, 0.0186]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1929
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.4200, 0.4506]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1930
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1090, 0.1189]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1931
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0842, 0.0918]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1932
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0098, 0.0108]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1933
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1443, 0.1562]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1934
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1986, 0.2148]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1935
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.2011, 0.2209]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1936
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0854, 0.0929]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1937
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0198, 0.0214]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1938
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0120, 0.0127]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1939
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0345, 0.0371]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1940
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0344, 0.0372]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1941
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.2953, 0.3193]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1942
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0252, 0.0270]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1943
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1431, 0.1554]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1944
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0738, 0.0804]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1945
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1171, 0.1279]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1946
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0623, 0.0676]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1947
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0473, 0.0512]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1948
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.2636, 0.2880]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1949
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0235, 0.0257]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1950
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0247, 0.0269]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1951
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1844, 0.2008]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1952
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0023, 0.0024]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1953
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0397, 0.0423]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1954
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1306, 0.1433]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1955
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0154, 0.0166]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1956
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0241, 0.0250]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1957
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0589, 0.0638]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1958
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0134, 0.0145]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1959
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0131, 0.0144]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1960
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0123, 0.0134]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1961
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0758, 0.0824]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1962
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0053, 0.0058]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1963
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.2234, 0.2417]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1964
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0618, 0.0666]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1965
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.4991, 0.5358]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1966
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0805, 0.0867]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1967
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0190, 0.0204]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1968
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0461, 0.0500]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1969
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.2558, 0.2791]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1970
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0082, 0.0085]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1971
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0149, 0.0163]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1972
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0003, 0.0002]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1973
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0152, 0.0163]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1974
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0578, 0.0625]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1975
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0091, 0.0098]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1976
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0066, 0.0070]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1977
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0368, 0.0399]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1978
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.2260, 0.2478]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1979
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1727, 0.1876]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1980
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.1439, 0.1539]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1981
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.0484, 0.0524]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1982
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0144, 0.0153]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1983
# data_instance.label: 1
# Prediction: 1
# node embeddings: tensor([[0.4503, 0.4803]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1984
# data_instance.label: 1
# Prediction: 0
# node embeddings: tensor([[0.0009, 0.0010]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1985
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0100, 0.0116]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1986
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0215, 0.0232]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1987
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0588, 0.0646]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1988
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0421, 0.0454]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1989
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0495, 0.0538]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1990
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.1176, 0.1287]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1991
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0121, 0.0130]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1992
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0230, 0.0244]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1993
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0110, 0.0115]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1994
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0165, 0.0177]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1995
# data_instance.label: 0
# Prediction: 1
# node embeddings: tensor([[0.0707, 0.0778]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1996
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0254, 0.0268]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1997
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0085, 0.0090]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1998
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0336, 0.0360]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 1999
# data_instance.label: 0
# Prediction: 0
# node embeddings: tensor([[0.0226, 0.0244]], dtype=torch.float64)
# ----------------------------------------------------------------
# data_instance.id: 2000
# data_instance.label: 0

# %%
file_name = max(os.listdir("..\\..\\explainability\GRETEL-repo\\output\\logs\\"), key=lambda f: os.path.getmtime(os.path.join("..\\..\\explainability\GRETEL-repo\\output\\logs\\", f)))
file_name = file_name.split('.')[0]
file_name = "..\\..\\explainability\GRETEL-repo\\output\\embeddings\\" + file_name + ".txt"

with open(file_name, "w") as f:
    f.write(captured_output.stdout)

# %% [markdown]
# ## Caricamento eval_manager

# %%
import os

# Ricava il nome del file di log più recente
def get_most_recent_file(folder_path):
    return max(os.listdir(folder_path), key=lambda f: os.path.getmtime(os.path.join(folder_path, f)))

folder_path = "..\\..\\explainability\GRETEL-repo\\output\\eval_manager\\"
most_recent_file_name = get_most_recent_file(folder_path)

file_path = folder_path + most_recent_file_name
file_path
# Out:
# '..\\..\\explainability\\GRETEL-repo\\output\\eval_manager\\23968-Martina.pkl'

# %%
import pickle

# Carica il dizionario da un file
with open(file_path, 'rb') as f:
    eval_manager = pickle.load(f)

# %%
import re

def get_oracle_and_explainer_names(eval_manager):
    string = eval_manager.evaluators[0].name

    oracle_name = re.search(r'using_(.*?)Oracle', string).group(1)
    if oracle_name == '': # Da controllare se è vero
        oracle_name = 'GCN'
    explainer_name = re.search(r'for_(.*?)Explainer', string).group(1)

    return f"{oracle_name} oracle - {explainer_name} explainer"

# %%
# eval_manager.evaluators[0].get_instance_and_counterfactual_classifications() # Non funziona

# %% [markdown]
# ## Visualizzazione dei risultati

# %%
import pickle

# Calcolo delle coordinate dei nodi

# OPZIONE 1: nodi su griglia regolare
# def generate_grid_positions(num_rows, num_cols):
#     """
#     Genera le posizioni dei nodi in una griglia regolare.

#     :param num_rows: Numero di righe nella griglia
#     :param num_cols: Numero di colonne nella griglia
#     :return: Dizionario con le posizioni dei nodi
#     """
#     positions = {}
#     node_id = 0
#     for r in range(num_rows):
#         for c in range(num_cols):
#             positions[node_id] = (c, -r)  # Posizionamento dei nodi nella griglia
#             node_id += 1
#     return positions

# Definizione delle posizioni fisse dei nodi con una griglia di 4x6
# fixed_positions = generate_grid_positions(4, 6)

#######################################################################################

# OPZIONE 2: coordinate predefinite
# Carica il dizionario delle coordinate dei punti medi da file
with open('dizionario_punti_medi.pkl', 'rb') as f:
    fixed_positions = pickle.load(f)

# %%
# # Funzione per disegnare la differenza tra grafo originario e sottografo date le matrici di adiacenza
# def plot_graph_difference(A_grafo, A_sottografo):
    
#     # Crea grafi da matrici di adiacenza
#     # G_grafo = nx.from_numpy_array(A_grafo)
#     G_sottografo = nx.from_numpy_array(A_sottografo)
#     G_differenza = nx.from_numpy_array(A_grafo - A_sottografo)

#     # Disegna il grafo differenza con linee tratteggiate
#     nx.draw(G_differenza, ax=ax, pos=fixed_positions, with_labels=True, node_color='skyblue', node_size=250,
#             font_size=8, edge_color='gray', style='dashed')

#     # Disegna il sottografo con linee piene
#     nx.draw(G_sottografo, ax=ax, pos=fixed_positions, with_labels=True, node_color='skyblue', node_size=250,
#             font_size=8, edge_color='black')

#     plt.title("Differenza tra il grafo principale e il sottografo")
#     plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt


# Funzione per disegnare la differenza tra grafo originario e la spiegazione date le matrici di adiacenza
def plot_graph_difference_updated(A_orig, A_expl):

    # Crea grafi da matrici di adiacenza
    G_orig = nx.from_numpy_array(A_orig)

    A_differenza = A_orig - A_expl
    archi_aggiunti = nx.from_numpy_array(A_differenza == -1)
    archi_rimossi = nx.from_numpy_array(A_differenza == 1)

    # Disegna il grafo originario
    nx.draw(G_orig, ax=ax, pos=fixed_positions, with_labels=True, node_color='skyblue', node_size=250,
            font_size=8, edge_color='black')

    # Disegna archi aggiunti
    nx.draw(archi_aggiunti, ax=ax, pos=fixed_positions, with_labels=True, node_color='skyblue', node_size=250,
            font_size=8, edge_color='green')

    # Disegna archi rimossi
    nx.draw(archi_rimossi, ax=ax, pos=fixed_positions, with_labels=True, node_color='skyblue', node_size=250,
            font_size=8, edge_color='red')

    plt.title("Grafo originario vs explainer")
    plt.show()

# %%
# Disegna i grafi e crea animazione

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.animation import writers
from IPython.display import HTML
import networkx as nx

# %matplotlib notebook

img = plt.imread("nodi-vuoto.png")

fig, ax = plt.subplots(figsize=(6,6))
fig.suptitle(get_oracle_and_explainer_names(eval_manager), fontsize=12.5, x = 0.51)

def animate(i):
    ax.clear()
    ax.imshow(img)

    g1, g2 = eval_manager._evaluators[0].get_instance_explanation_pairs()[i]
    # plot_graph_difference(g1.data, g2.data)
    plot_graph_difference_updated(g1.data, g2.data)

    ax.set_title(f'Graph id: {g1.id} (classe: {g1.label})')

ani = FuncAnimation(fig, animate, frames=len(eval_manager._evaluators[0].get_instance_explanation_pairs()), repeat=False, blit=True)
ani.save("..\\..\\explainability\GRETEL-repo\\output\\video\\evoluzione_sottografi_" + most_recent_file_name.split('.')[0] + ".mp4", writer="ffmpeg", fps=10)

HTML(ani.to_jshtml())
# Out:
# <div id='b3a810b2-48e5-4f1c-9c80-5312726c3e32'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 26
#      22     plot_graph_difference_updated(g1.data, g2.data)
#      24     ax.set_title(f'Graph id: {g1.id} (classe: {g1.label})')
# ---> 26 ani = FuncAnimation(fig, animate, frames=len(eval_manager._evaluators[0].get_instance_explanation_pairs()), repeat=False, blit=True)
#      27 ani.save("..\\..\\explainability\GRETEL-repo\\output\\video\\evoluzione_sottografi_" + most_recent_file_name.split('.')[0] + ".mp4", writer="ffmpeg", fps=10)
#      29 HTML(ani.to_jshtml())
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# ## _______________________________________________________________

# %%
import datetime

now = datetime.datetime.now()
print("Ultima esecuzione completa:", now.strftime("%d/%m/%Y, ore %H:%M"))
# Out:
# Ultima esecuzione completa: 07/01/2025, ore 09:20

# %%
# Per lettura log e plot metriche: notebook "Lettura_EEG"
